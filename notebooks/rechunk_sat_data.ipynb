# %%
import xarray as xr
import pandas as pd
from pathlib import Path
import numcodecs
import gcsfs
import dask

# %%
import rechunker

# %%
BUCKET = Path('solar-pv-nowcasting-data')
SAT_PATH = BUCKET / 'satellite/EUMETSAT/SEVIRI_RSS/OSGB36/'
SOURCE_SAT_FILENAME = 'gs://' + str(SAT_PATH / 'all_zarr_int16')
TARGET_SAT_FILENAME = SAT_PATH / 'all_zarr_int16_single_timestep_uint8.zarr'
TEMP_STORE_FILENAME = SAT_PATH / 'temp.zarr'

# %%
source_sat_dataset = xr.open_zarr(SOURCE_SAT_FILENAME, consolidated=True)

# %%
# Need to select at chunk boundaries!
source_sat_dataset = source_sat_dataset.isel(time=slice(0, 3600))

# %%
source_sat_dataset['stacked_eumetsat_data']
# Out:
# <xarray.DataArray 'stacked_eumetsat_data' (time: 3600, y: 704, x: 548, variable: 12)>
# dask.array<getitem, shape=(3600, 704, 548, 12), dtype=int16, chunksize=(36, 704, 548, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time      (time) datetime64[ns] 2018-06-01T02:04:00 ... 2018-06-13T18:14:00
#   * variable  (variable) <U6 'HRV' 'IR_016' 'IR_039' ... 'WV_062' 'WV_073'
#   * x         (x) int64 -238000 -236000 -234000 -232000 ... 852000 854000 856000
#   * y         (y) int64 1222000 1220000 1218000 ... -180000 -182000 -184000

# %%
gcs = gcsfs.GCSFileSystem()

# %%
target_store = gcs.get_mapper(TARGET_SAT_FILENAME)

# %%
temp_store = gcs.get_mapper(TEMP_STORE_FILENAME)

# %%
target_chunks = {
    'stacked_eumetsat_data': {
        "time": 1,
        "y": 704,
        "x": 548,
        "variable": 1,
    }
}

encoding = {
    'stacked_eumetsat_data': {
        'compressor': numcodecs.Blosc(cname="zstd", clevel=5),
    }
}

rechunk_plan = rechunker.rechunk(
    source=source_sat_dataset,
    target_chunks=target_chunks,
    max_mem="10GB",
    target_store=target_store,
    target_options=encoding,
    temp_store=temp_store
)

# %%
# %%time
rechunk_plan.execute()
# Out:
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(252, 288, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1404, 1440, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3384, 3420, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(612, 648, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))_copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
#
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))_copy_chunk((slice(1044, 1080, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
#
# _copy_chunk((slice(3024, 3060, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(252, 288, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2232, 2268, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))_copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
#
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3384, 3420, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2664, 2700, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))_copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
#
# _copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))_copy_chunk((slice(1872, 1908, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
#
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3024, 3060, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))_copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
#
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2232, 2268, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1512, 1548, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(720, 756, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2664, 2700, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))_copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
#
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1872, 1908, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(360, 396, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1512, 1548, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3492, 3528, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(720, 756, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))_copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
#
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))_copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
#
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(360, 396, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3492, 3528, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(720, 756, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2664, 2700, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(360, 396, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))_copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
#
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))_copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
#
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1620, 1656, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(828, 864, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(36, 72, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1620, 1656, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(828, 864, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2808, 2844, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(36, 72, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2448, 2484, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1656, 1692, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2808, 2844, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2088, 2124, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))_copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
#
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2448, 2484, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1656, 1692, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))_copy_chunk((slice(936, 972, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
#
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2088, 2124, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(3276, 3312, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))_copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
#
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(936, 972, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2916, 2952, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(144, 180, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2124, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))_copy_chunk((slice(612, 648, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
#
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3276, 3312, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2556, 2592, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(936, 972, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2916, 2952, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(144, 180, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2124, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2556, 2592, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1764, 1800, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))_copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
#
# _copy_chunk((slice(2916, 2952, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2124, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1404, 1440, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(612, 648, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2556, 2592, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))_copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
#
# _copy_chunk((slice(1764, 1800, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1044, 1080, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))_copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
#
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(252, 288, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1404, 1440, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3384, 3420, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(612, 648, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1044, 1080, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3024, 3060, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(252, 288, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2232, 2268, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1476, 1512, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3384, 3420, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2664, 2700, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1872, 1908, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1800, 1836, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3024, 3060, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(252, 288, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2232, 2268, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1512, 1548, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))_copy_chunk((slice(3456, 3492, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
#
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(684, 720, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2664, 2700, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1872, 1908, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3096, 3132, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))_copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
#
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(324, 360, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1512, 1548, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3492, 3528, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1440, 1476, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3420, 3456, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(720, 756, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1872, 1908, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1080, 1116, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(360, 396, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2304, 2340, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(288, 324, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2268, 2304, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1512, 1548, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3492, 3528, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(36, 72, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(720, 756, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))_copy_chunk((slice(1116, 1152, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
#
# _copy_chunk((slice(3060, 3096, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(360, 396, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2808, 2844, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3492, 3528, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))_copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
#
# _copy_chunk((slice(756, 792, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2700, 2736, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1908, 1944, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1656, 1692, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1620, 1656, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1548, 1584, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3528, 3564, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(828, 864, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))_copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
#
# _copy_chunk((slice(2736, 2772, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(36, 72, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))_copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
#
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# ...
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1188, 1224, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3168, 3204, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2448, 2484, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1152, 1188, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(396, 432, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1620, 1656, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2340, 2376, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(828, 864, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2808, 2844, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(36, 72, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(0, 36, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1944, 1980, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2448, 2484, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3132, 3168, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2376, 2412, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1656, 1692, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(1584, 1620, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2808, 2844, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2088, 2124, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(792, 828, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2016, 2052, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1980, 2016, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1224, 1260, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2448, 2484, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(432, 468, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(1656, 1692, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(936, 972, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1620, 1656, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(3564, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(864, 900, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(144, 180, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2088, 2124, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(2772, 2808, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(72, 108, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1296, 1332, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(3276, 3312, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(3204, 3240, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(504, 540, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(468, 504, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2412, 2448, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(936, 972, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(2916, 2952, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))_copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
#
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(2844, 2880, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(144, 180, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2124, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))_copy_chunk((slice(1368, 1404, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
#
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(2052, 2088, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(3276, 3312, None), slice(0, 704, None), slice(0, 548, None), slice(9, 10, None)))
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2556, 2592, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1260, 1296, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(3240, 3276, None), slice(0, 704, None), slice(0, 548, None), slice(3, 4, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2484, 2520, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(1764, 1800, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(1692, 1728, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(2916, 2952, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
# _copy_chunk((slice(144, 180, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2124, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1404, 1440, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(108, 144, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3348, 3384, None), slice(0, 704, None), slice(0, 548, None), slice(8, 9, None)))
# _copy_chunk((slice(2088, 2124, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))_copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(2, 3, None)))
#
# _copy_chunk((slice(576, 612, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2556, 2592, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(1764, 1800, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1008, 1044, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2988, 3024, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(972, 1008, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(2952, 2988, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))
# _copy_chunk((slice(216, 252, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2196, 2232, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(900, 936, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(2880, 2916, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(180, 216, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2160, 2196, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1404, 1440, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(3384, 3420, None), slice(0, 704, None), slice(0, 548, None), slice(1, 2, None)))_copy_chunk((slice(648, 684, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
#
# _copy_chunk((slice(2628, 2664, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1332, 1368, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(3312, 3348, None), slice(0, 704, None), slice(0, 548, None), slice(7, 8, None)))
# _copy_chunk((slice(612, 648, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(2592, 2628, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1836, 1872, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(540, 576, None), slice(0, 704, None), slice(0, 548, None), slice(10, 11, None)))
# _copy_chunk((slice(2520, 2556, None), slice(0, 704, None), slice(0, 548, None), slice(6, 7, None)))
# _copy_chunk((slice(1764, 1800, None), slice(0, 704, None), slice(0, 548, None), slice(11, 12, None)))
# _copy_chunk((slice(1044, 1080, None), slice(0, 704, None), slice(0, 548, None), slice(4, 5, None)))
# _copy_chunk((slice(3024, 3060, None), slice(0, 704, None), slice(0, 548, None), slice(0, 1, None)))
# _copy_chunk((slice(1728, 1764, None), slice(0, 704, None), slice(0, 548, None), slice(5, 6, None)))
# _copy_chunk((slice(0, 3600, None),))
# _copy_chunk((slice(0, 548, None),))
# _copy_chunk((slice(0, 704, None),))
# _copy_chunk((slice(0, 12, None),))
# _copy_chunk((slice(0, 2160, None), slice(0, 704, None), slice(0, 548, None), slice(0, 12, None)))_copy_chunk((slice(2160, 3600, None), slice(0, 704, None), slice(0, 548, None), slice(0, 12, None)))
#
# CPU times: user 39min 29s, sys: 33.3 s, total: 40min 2s
# Wall time: 11min 44s
# <zarr.hierarchy.Group '/'>

# %%
opened_dataset = xr.open_zarr(f'gs://{TARGET_SAT_FILENAME}', consolidated=False)

# %%
opened_dataset
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 3600, variable: 12, x: 548, y: 704)
# Coordinates:
#   * time                   (time) datetime64[ns] 2018-06-01T02:04:00 ... 2018...
#   * variable               (variable) <U6 'HRV' 'IR_016' ... 'WV_062' 'WV_073'
#   * x                      (x) int64 -238000 -236000 -234000 ... 854000 856000
#   * y                      (y) int64 1222000 1220000 1218000 ... -182000 -184000
# Data variables:
#     stacked_eumetsat_data  (time, y, x, variable) uint8 dask.array<chunksize=(1, 704, 548, 1), meta=np.ndarray>

# %%
f'gs://{TARGET_SAT_FILENAME}'
